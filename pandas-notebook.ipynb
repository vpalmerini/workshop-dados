# %%
# importação das bibliotecas
import pandas as pd
from fuzzywuzzy import fuzz, process
# Out:
# /home/victorpalmerini/Documentos/workshop-dados/env-notebook/lib/python3.6/site-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
# read csv
df = pd.read_csv('MailingTalento2018.csv')

# %%
df
# Out:
#       Unnamed: 0                           NomeCompleto  \
# 0              0                    Caio César Suguiuti
# 1              1                         Giulia Benutto
# 2              2                       Bruno Leme Valle
# 3              3                  Maria Isabel da Silva
# 4              4                     Sarah Regina Bueno
# 5              5                       Stela Tellarolli
# 6              6                        Victor Mendonça
# 7              7                  Luis Miguel Ticianeli
# 8              8               Tatiane Fernandes Furlan
# 9              9             Alexandre Ribeiro Da Cunha
# 10            10                           Bianca Mello
# 11            11                           Giulia Silva
# 12            12          Melissa Formisano Paccagnella
# 13            13         Marina Augusto Risso de Castro
# 14            14                       Márcio Gabrielli
# 15            15                             Maira Goes
# 16            16                Ester de Paula oliveira
# 17            17                      Lucas Zangerolamo
# 18            18         José Antonio Schewinsky Junior
# 19            19                        Jamile Custodio
# 20            20                    Bruno Teles Risonho
# 21            21                Guilherme Bersi Pereira
# 22            22                      Marcos Pszybylski
# 23            23                             Lucas Tuão
# 24            24                      Naiara Nascimento
# 25            25  Maria Manuela Vidigal Pacheco e Silva
# 26            26                 Samuel Buglini Casarin
# 27            27                        Beatriz Cardoso
# 28            28              Marilia Mugnol dos Santos
# 29            29                    Melissa Paccagnella
# ...          ...                                    ...
# 6588        6588                       Gabriel Pastrelo
# 6589        6589                       Gustavo Guaragna
# 6590        6590                       Roberto Gaudeuso
# 6591        6591                Caroline Lima Penhalves
# 6592        6592                         Mayla de Souza
# 6593        6593                       Alexandre Morais
# 6594        6594                       Wellington Costa
# 6595        6595                          Waina Linares
# 6596        6596            Caio Henrique De Sousa Lima
# 6597        6597                      Vanessa Furnaleto
# 6598        6598         Matheus Roberto Faria da Silva
# 6599        6599                                    NaN
# 6600        6600                                    NaN
# 6601        6601                    Gabriel Baptistussi
# 6602        6602                          Larissa Denny
# 6603        6603                     João Vitor Beraldo
# 6604        6604                         Caroline Deise
# 6605        6605                                    NaN
# 6606        6606                 Pedro Alexandroni Dias
# 6607        6607             João Victor Marino Barbosa
# 6608        6608                                    NaN
# 6609        6609                           Vitor Mourão
# 6610        6610                       Serena Venturini
# 6611        6611          Heitor Benito Darros Terceiro
# 6612        6612                          Gustavo Lessa
# 6613        6613                                    NaN
# 6614        6614                Matheus Do Valle Liasch
# 6615        6615                       Pep Gomes Franco
# 6616        6616                     Thawany Gullinelli
# 6617        6617                      Vyctoria da Silva
#
#                                        Email        Telefone  Idade Gênero  \
# 0                          temp_60@email.com             NaN    NaN    NaN
# 1                   giuliabenuttos@gmail.com  (19)98118-3994   21.0      F
# 2                         brunolv6@gmail.com  (11)96404-6615   26.0      M
# 3              mariaisabel332010@hotmail.com  (19)99727-9462   18.0      F
# 4                    sarah.r.bueno@gmail.com  (19)99354-1694   25.0      F
# 5                     sttellarolli@gmail.com  (27)99231-0602   20.0      F
# 6                 victorammendonca@gmail.com  (19)98133-5651   24.0      M
# 7                   luismticianeli@gmail.com  (16)98110-8920   20.0      M
graduação  https://talentoprod.s3.amazonaws.com/uploads/c...
# 2        Graduação                                                NaN
# 3        Graduação                                                NaN
# 4        Graduação  https://linkedin.com/in/sarah-regina-bueno-4a1...
# 5        Graduação                                                NaN
# 6        Graduação  https://www.linkedin.com/in/victor-mendonça-71...
# 7        Graduação                                                NaN
# 8        Graduação  https://talentoprod.s3.amazonaws.com/uploads/c...
# 9              NaN                                                NaN
# 10             NaN                                                NaN
# 11       Graduação  file:///C:/Users/User/Downloads/curriculo_cia_...
# 12       Graduação                                                NaN
# 13       Graduação  https://talentoprod.s3.amazonaws.com/uploads/c...
# 14       Doutorado            https://lattes.cnpq.br/2043804470198910
# 15             NaN                                                NaN
# 16    Ensino Médio                                                NaN
# 17       Graduação                       https://Avenida Santa Isabel
# 18       Graduação  https://linkedin.com/in/junior-schewinsky-418a...
# 19    Ensino Médio                                                NaN
# 20       Graduação                                                NaN
# 21       Graduação  https://talentoprod.s3.amazonaws.com/uploads/c...
# 22       Graduação                                                NaN
# 23       Graduação                                                NaN
# 24             NaN                                                NaN
# 25       Graduação  https://talentoprod.s3.amazonaws.com/uploads/c...
# 26       Graduação                                                NaN
# 27             NaN                                                NaN
# 28       Graduação  https://talentoprod.s3.amazonaws.com/uploads/c...
# 29             NaN                                                NaN
# ...            ...                                                ...
# 6588     Graduação                                                NaN
# 6589     Graduação                                                NaN
# 6590     Graduação                                                NaN
# 6591     Graduação  https://talentoprod.s3.amazonaws.com/uploads/c...
# 6592  Ensino Médio     https://linkedin.com/in/in/mayladesouza140397/
# 6593           NaN                                                NaN
# 6594     Graduação  file:///C:/Users/User/Desktop/Cv%20-%20Welling...
# 6595     Graduação  https://buscatextual.cnpq.br/buscatextual/visu...
# 6596     Graduação                                                NaN
# 6597     Graduação                                                NaN
# 6598     Graduação  https://talentoprod.s3.amazonaws.com/uploads/c...
# 6599           NaN                                                NaN
# 6600           NaN                                                NaN
# 6601        Brasil                https://linkedin.com/in/baptistussi
# 6602     Graduação                                                NaN
# 6603     Graduação                                                NaN
# 6604     Graduação                                                NaN
# 6605           NaN                                                NaN
# 6606  Ensino Médio                                                NaN
# 6607     Graduação  https://talentoprod.s3.amazonaws.com/uploads/c...
# 6608           NaN                                                NaN
# 6609     Graduação                                                NaN
# 6610     Graduação                                                NaN
# 6611     Graduação                                                NaN
# 6612     Graduação                                                NaN
# 6613           NaN                                                NaN
# 6614     Graduação                                                NaN
# 6615     Graduação                                                NaN
# 6616     Graduação                                                NaN
# 6617     Graduação             https://linkedin.com/in/vyctoriakarina
#
#                                              Currículo2 AnoDeEntrada  \
# 0                                                   NaN          NaN
# 1                                                   NaN         2017
# 2                                                   NaN         2018
# 3                                                   NaN         2018
# 4                                                   NaN         2016
# 5                                                   NaN         2016
# 6                                                   NaN         2015
# 7                                                   NaN         2017
# 8                                                   NaN         2013
# 9                                                   NaN          NaN
# 10                                                  NaN          NaN
# 11                                                  NaN         2015
# 12                                                  NaN         2014
# 13                                                  NaN         2015
# 14                                                  NaN         2015
# 15                                                  NaN          NaN
# 16                                                  NaN         2018
# 17                                                  NaN         2014
# 18                                                  NaN         2016
# 19                                                  NaN         2016
# 20                                                  NaN         2018
# 21               https://linkedin.com/in/guilhermebersi         2013
# 22                                                  NaN         2008
# 23                                                  NaN         2015
# 24                                                  NaN          NaN
# 25               https://linkedin.com/in/manuelapacheco         2015
# 26                                                  NaN         2013
# 27                                                  NaN          NaN
# 28    https://linkedin.com/in/marília-mugnol-dos-san...         2013
# 29                                                  NaN          NaN
# ...                                                 ...          ...
# 6588                                                NaN         2016
# 6589                                                NaN         2018
# 6590                                                NaN         2016
# 6591  https://linkedin.com/in/caroline-penhalves-656...         2014
# 6592                                                NaN         2012
# 6593                                                NaN          NaN
# 6594                                                NaN         2018
# 6595                                                NaN         2017
# 6596                                                NaN         2018
# 6597                                                NaN         2014
# 6598                                                NaN         2018
# 6599                                                NaN          NaN
# 6600                                                NaN          NaN
# 6601                                                NaN         2011
# 6602                                                NaN         2017
# 6603                                                NaN         2016
# 6604                                                NaN         2016
# 6605                                                NaN          NaN
# 6606                                                NaN         2014
# 6607                                                NaN         2015
# 6608                                                NaN          NaN
# 6609                                                NaN         2015
# 6610                                                NaN         2012
# 6611                                                NaN         2016
# 6612                                                NaN         2016
# 6613                                                NaN          NaN
# 6614                                                NaN         2018
# 6615                                                NaN         2017
# 6616                                                NaN         2018
# 6617                                                NaN         2017
#
#          ...        País        Inglês         Excel  \
# 0        ...         NaN           NaN           NaN
# 1        ...      Brasil  intermediate         basic
# 2        ...      Brasil           NaN           NaN
# 3        ...      Brasil  intermediate      advanced
# 4        ...      Brasil  intermediate         basic
# 5        ...      Brasil      advanced         basic
# 6        ...      Brasil      advanced  intermediate
# 7        ...         NaN           NaN           NaN
# 8        ...      Brasil      advanced      advanced
# 9        ...         NaN           NaN           NaN
# 10       ...         NaN           NaN           NaN
# 11       ...      Brasil  intermediate  intermediate
# 12       ...      Brasil      advanced  intermediate
# 13       ...      Brasil      advanced  intermediate
# 14       ...      Brasil  intermediate      advanced
# 15       ...         NaN           NaN           NaN
# 16       ...      Brasil         basic  intermediate
# 17       ...         NaN           NaN           NaN
# 18       ...      Brasil      advanced      advanced
# 19       ...         NaN           NaN           NaN
# 20       ...      Brasil  intermediate      advanced
# 21       ...      Brasil      advanced  intermediate
# 22       ...         NaN           NaN           NaN
# 23       ...         NaN           NaN           NaN
# 24       ...         NaN           NaN           NaN
# 25       ...      Brasil      advanced      advanced
# 26       ...         NaN           NaN           NaN
# 27       ...         NaN           NaN           NaN
# 28       ...      Brasil      advanced  intermediate
# 29       ...         NaN           NaN           NaN
# ...      ...         ...           ...           ...
# 6588     ...      Brasil           NaN           NaN
# 6589     ...         NaN           NaN           NaN
# 6590     ...         NaN           NaN           NaN
# 6591     ...      Brasil  intermediate  intermediate
# 6592     ...      Brasil  intermediate         basic
# 6593     ...         NaN           NaN           NaN
# 6594     ...      Brasil         basic  intermediate
# 6595     ...      Brasil  intermediate         basic
# 6596     ...         NaN           NaN           NaN
# 6597     ...         NaN           NaN           NaN
# 6598     ...      Brasil         basic           NaN
# 6599     ...         NaN           NaN           NaN
# 6600     ...         NaN           NaN           NaN
# 6601     ...      Brasil      advanced      advanced
# 6602     ...         NaN           NaN           NaN
# 6603     ...      Brasil  intermediate  intermediate
# 6604     ...         NaN           NaN           NaN
# 6605     ...         NaN           NaN           NaN
# 6606     ...         NaN           NaN           NaN
# 6607     ...      Brasil           NaN  intermediate
# 6608     ...         NaN           NaN           NaN
# 6609     ...         NaN           NaN           NaN
# 6610     ...         NaN           NaN           NaN
# 6611     ...         NaN           NaN           NaN
# 6612     ...         NaN           NaN           NaN
# 6613     ...         NaN           NaN           NaN
# 6614     ...         NaN           NaN           NaN
# 6615     ...         NaN           NaN           NaN
# 6616     ...         NaN           NaN           NaN
# 6617     ...      Brasil      advanced  intermediate
#
#                                           Cursos Extras  \
# 0                                                   NaN
# 1     Inglês pela plataforma My English Online (Mini...
# 2                                Excel Avancado (SENAC)
# 3                                           Informática
# 4                                                   NaN
# 5                                                   NaN
# 6                                                   NaN
# 7                                                   NaN
# 8     Excel Aplicado à Engenharia - Do Básico ao Ava...
# 9                                                   NaN
# 10                                                  NaN
# 11                                                  NaN
# 12                                                  NaN
# 13                                                  NaN
# 14                      Licenciamento Ambiental (SENAC)
# 15                                                  NaN
# 16                                                  NaN
# 17                                                  NaN
# 18                              Cursos da área da Udemy
# 19                                                  NaN
# 20               Técnico de Informática, Pacote Office.
# 21                                                  NaN
# 22                                                  NaN
# 23                                                  NaN
# 24                                                  NaN
# 25                                                  NaN
# 26                                                  NaN
# 27                                                  NaN
# 28    General Business Program (BTC), Marketing Estr...
# 29                                                  NaN
# ...                                                 ...
# 6588                                                NaN
# 6589                                                NaN
# 6590                                                NaN
# 6591                                                NaN
# 6592   Técnico em Secretariado pela ETEC de Hortolândia
# 6593                                                NaN
# 6594                                        Informática
# 6595  Avaliação do risco de queda de árvores urbanas...
# 6596                                                NaN
# 6597                                                NaN
# 6598                                                NaN
# 6599                                                NaN
# 6600                                                NaN
# 6601                                        Yellow Belt
# 6602                                                NaN
# 6603                                                NaN
# 6604                                                NaN
# 6605                                                NaN
# 6606                                                NaN
# 6607                                                NaN
# 6608                                                NaN
# 6609                                                NaN
# 6610                                                NaN
# 6611                                                NaN
# 6612                                                NaN
# 6613                                                NaN
# 6614                                                NaN
# 6615                                                NaN
# 6616                                                NaN
# 6617            Python, C#, Redes, Informática avançada
#
#                                Outros Idiomas  \
# 0                                         NaN
# 1                             Espanhol báscio
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# 5                                         NaN
# 6                                         NaN
# 7                                         NaN
# 8                            Francês Avançado
# 9                                         NaN
# 10                                        NaN
# 11                                        NaN
# 12                            Italiano básico
# 13    Inglês Avançado, Espanhol Intermediário
# 14                   Espanhol (Intermediário)
# 15                                        NaN
# 16                                        NaN
# 17                                        NaN
# 18                     Espanhol Intermediário
# 19                                        NaN
# 20                                        NaN
# 21                     Espanhol intermediário
# 22                                        NaN
# 23                                        NaN
# 24                                        NaN
# 25                                        NaN
# 26                                        NaN
# 27                                        NaN
# 28                                        NaN
# 29                                        NaN
# ...                                       ...
# 6588                                      NaN
# 6589                                      NaN
# 6590                                      NaN
# 6591                                      NaN
# 6592                                      NaN
# 6593                                      NaN
# 6594                                      NaN
# 6595                                      NaN
# 6596                                      NaN
# 6597                                      NaN
# 6598                                      NaN
# 6599                                      NaN
# 6600                                      NaN
# 6601                          Espanhol básico
# 6602                                      NaN
# 6603                                      NaN
# 6604                                      NaN
# 6605                                      NaN
# 6606                                      NaN
# 6607                                      NaN
# 6608                                      NaN
# 6609                                      NaN
# 6610                                      NaN
# 6611                                      NaN
# 6612                                      NaN
# 6613                                      NaN
# 6614                                      NaN
# 6615                                      NaN
# 6616                                      NaN
# 6617                                      NaN
#
#                                              Interesses Pode se mudar  \
# 0                                                   NaN           NaN
# 1            Industria, educação, pesquisa e hospitalar          True
# 2     Financeiro, pesquisa, excel, design thinking e...          True
# 3                                            Financeiro          True
# 4                            Pesquisa e desenvolvimento         False
# 5                               Consultoria, manutenção         False
# 6             Liderança, mercado financeiro, consutoria          True
# 7                 Tecnologia, Empresarial e Consultoria         False
# 8           Consultoria, Estratégia e Gestão, Operações          True
# 9                                                   NaN           NaN
# 10                                                  NaN           NaN
# 11                                            Qualidade         False
# 12    Controle de Qualidade, Gerenciamento de Qualidade          True
# 13    Recursos Humanos, Marketing, Financeiro, Admin...          True
# 14                            Saneamento, Meio Ambiente         False
# 15                                                  NaN           NaN
# 16                                 finaceiro, pesquisas          True
# 17                                             Pesquisa         False
# 18                                         Data Science         False
# 19                                        administração         False
# 20                 Contabilidade, finanças, estatistica          True
# 21                                           Engenharia         False
# 22                                           Financeiro         False
# 23                              Pesquisa, parte técnica         False
# 24                                                  NaN           NaN
# 25    Consultoria, além de indústrias de alimentos e...          True
# 26                  Engenharia, consultoria, financeira         False
# 27                                                  NaN           NaN
# 28                   Consultoria,  Planejamento, Gestão          True
# 29                                                  NaN           NaN
# ...                                                 ...           ...
# 6588  Engenharia de qualidade, Logística, Ambiental,...         False
# 6589                               Financeiro, pesquisa         False
# 6590                                  Mecanica em geral         False
# 6591                PCP, Auditoria, Gestão da Qualidade          True
# 6592                        Administração, Secretariado         False
# 6593                                                NaN           NaN
# 6594                          Consultoria e Atendimento         False
# 6595          Pesquisa em botânica, ecologia e anatomia         False
# 6596                                         Financeiro         False
# 6597                                Engenharia, Quimica         False
# 6598                             eletrônica, automação,          True
# 6599                                                NaN           NaN
# 6600                                                NaN           NaN
# 6601        Engenharia, Manutenção, TI, Desenvolvimento          True
# 6602                                               Tudo         False
# 6603                   Indústria, inovação e tecnologia          True
# 6604                                           pesquisa         False
# 6605                                                NaN           NaN
# 6606                                         financeiro         False
# 6607                                Desenvolvimento web          True
# 6608                                                NaN           NaN
# 6609                                           Finanças         False
# 6610                       Psicologia, recursos humanos         False
# 6611      Mercado financeiro, comércio exterior, bancos         False
# 6612                                         Engenharia         False
# 6613                                                NaN           NaN
# 6614                       Economia, gestão de recursos         False
# 6615  Pesquisa, planejamento urbano, patrimonio cult...         False
# 6616                                                 RH         False
# 6617                                                 TI         False
#
#      Primeira Vez                   Referência      Status
# 0             NaN                          NaN  unverified
# 1            True          através do facebook   confirmed
# 2            True                     Facebook   checkedin
# 3           False                       Amigos  unverified
# 4            True                       Amigos   confirmed
# 5            True                     Facebook    admitted
# 6            True                     Facebook   checkedin
# 7            True                     Facebook   confirmed
# 8            True                     Facebook   confirmed
# 9             NaN                          NaN  incomplete
# 10            NaN                          NaN  incomplete
# 11          False                        Amigo   checkedin
# 12           True                     Facebook    withdraw
# 13          False                     Facebook   confirmed
# 14           True                        amigo   confirmed
# 15            NaN                          NaN  incomplete
# 16           True                        amigo   confirmed
# 17          False     Já visitei outras vezes.   confirmed
# 18           True                     Facebook   confirmed
# 19           True                        Senac   checkedin
# 20           True                        Amigo    admitted
# 21          False                     Facebook   checkedin
# 22          False                       Amigos   checkedin
# 23          False                     Facebook   checkedin
# 24            NaN                          NaN  incomplete
# 25           True                       Amigos   checkedin
# 26          False                        Amigo   confirmed
# 27            NaN                          NaN  incomplete
# 28          False                     Facebook   confirmed
# 29            NaN                          NaN  incomplete
# ...           ...                          ...         ...
# 6588         True  Facebook, Amigos, Faculdade   checkedin
# 6589         True                        Amigo   checkedin
# 6590         True             Amigos indicacao   checkedin
# 6591        False                     Parentes   checkedin
# 6592         True               Por familiares   checkedin
# 6593          NaN                          NaN  incomplete
# 6594         True                      Parente    withdraw
# 6595         True                Matéria do G1   checkedin
# 6596         True                         Amig   checkedin
# 6597         True                         Site   checkedin
# 6598         True                         EPTV    admitted
# 6599          NaN                          NaN  incomplete
# 6600          NaN                          NaN  incomplete
# 6601         True                        Amigo   checkedin
# 6602         True                     Facebook   checkedin
# 6603        False                     Facebook   checkedin
# 6604         True                       E-mail   checkedin
# 6605          NaN                          NaN  incomplete
# 6606         True                        amigo   checkedin
# 6607         True             Através de amigo    admitted
# 6608          NaN                          NaN  incomplete
# 6609         True                      Unicamp   checkedin
# 6610         True    Visualizou, redes sociais   checkedin
# 6611        False                       Amigos   checkedin
# 6612         True                      Unicamp   checkedin
# 6613          NaN                          NaN  incomplete
# 6614        False                     Facebook   checkedin
# 6615         True                 Visualizando   checkedin
# 6616        False           ediçoes anteriores   checkedin
# 6617         True                        Amigo    withdraw
#
# [6618 rows x 24 columns]

# %%
# drop null values
df = df.dropna(subset=['NomeCompleto', 'Email', 'Curso'])

# %%
# remove duplicates
df = df.drop_duplicates(subset=['Email'], keep='first')

# %%
# string matching - courses
courses = 	['Administração', 
			'Análise de Sistemas', 
			'Arquitetura',
			'Artes Cênicas',
			'Artes Visuais',
			'Biologia',
			'Biomedicina',
			'Ciência da Computação',
			'Ciências Contábeis',
			'Ciências Econômicas',
			'Ciência Sociais',
			'Comunicação',
			'Dança',
			'Design',
			'Direito',
			'Economia',
			'Educação Física',
			'Enfermagem',
			'Engenharia Agrícola',
			'Engenharia Ambiental',
			'Engenharia Civil',
			'Engenharia da Computação',
			'Engenharia de Controle e Automação',
			'Engenharia de Manufatura',
			'Engenharia de Materiais',
			'Engenharia de Produção',
			'Engenharia de Software',
			'Engenharia Elétrica',
			'Engenharia Física',
			'Engenharia Mecânica',
			'Engenharia Química',
			'Estatística',
			'Farmácia',
			'Filosofia'
			'Física',
			'Fisioterapia',
			'Fonoaudiologia',
			'Geografia',
			'Geologia',
			'História',
			'Jornalismo',
			'Letras',
			'Linguística',
			'Logística',
			'Marketing',
			'Matemática',
			'Medicina',
			'Medicina Veterinária',
			'Midialogia',
			'Moda',
			'Música',
			'Nutrição',
			'Odontologia',
			'Pedagogia',
			'Psicologia',
			'Publicidade e Propaganda',
			'Química',
			'Relações Internacionais',
			'Relações Públicas',
			'Sistemas de Informação'
			]

for i in range(len(df['Curso'])):
	for course in courses:
		if (fuzz.token_set_ratio(course, df['Curso'][i]) > 90):
			df['Curso'][i] = course

# %%
# string matching - universities
universities =	['Unicamp',
				'USP',
				'Unesp',
				'Mackenzie',
				'PUCCAMP',
				'FACAMP',
				'ESAMC',
				'FATEC',
				'FGV',
				'ITA',
				'PUC',
				'UFSCAR',
				]

for i in range(len(df['Faculdade'])):
	for university in universities:
		if (fuzz.token_set_ratio(university, df['Faculdade'][i]) > 90):
			df['Faculdade'][i] = university

# %%
# string matching - cities
cities = ['Campinas',
		  'São Paulo',
		  'Limeira',
		  'São Carlos',
		  'Bauru',
		  'São José dos Campos',
		  'Piracicaba',
		  'Jundiaí',
		]

for i in range(len(df['Cidade'])):
	for city in cities:
		if (fuzz.token_set_ratio(city, df['Cidade'][i]) > 90):
			df['Cidade'][i] = city

# %%
# string matching - referrers
referrers = ['Facebook',
			 'Email',
			 'Amigos'
			 'Unicamp',
			 'Universidade'
		]

for i in range(len(df['Referência'])):
	for referrer in referrers:
		if (fuzz.token_set_ratio(referrer, df['Referência'][i]) > 90):
			df['Referência'][i] = referrer

# %%
# subscription data
total = len(df)
subscribed = len(df.loc[df['Idade'].notna() == True])
checkedin = len(df.loc[df['Status'] == 'checkedin'])

# %%
# age
# remove weird values
age = df.loc[df['Idade'] < 75]
# get the average
age_avg = age.mean()['Idade']

# %%
# gender
male = len(df.loc[df['Gênero'] == 'M'])
female = len(df.loc[df['Gênero'] == 'F'])

# %%
# cities
cities = df.groupby('Cidade').size()
cities = cities.sort_values(ascending=False)
cities_top10 = cities[:10]

# %%
# first time as Talento's visitor
first_time = len(df.loc[df['Primeira Vez'] == 'True'])
not_first_time = total - first_time

# %%
# referrer
facebook = len(df.loc[df['Referência'] == 'Facebook'])
email = len(df.loc[df['Referência'] == 'Email'])
friends = len(df.loc[df['Referência'] == 'Amigos'])
others = total - (facebook + email + friends)

# %%
# main courses
courses = df.groupby('Curso').size()
courses = courses.sort_values(ascending=False)
courses_top10 = courses[:10]

# %%
# enroll year
enroll_year = df.groupby('AnoDeEntrada').size()
enroll_year = enroll_year.sort_values(ascending=False)
enroll_year_top5 = enroll_year[:5]

# %%
# universities
universities = df.groupby('Faculdade').size()
universities = universities.sort_values(ascending=False)
universities_top10 = universities[:10]

# %%
# english level
basic_english = len(df.loc[df['Inglês'] == 'basic'])
intermediate_english = len(df.loc[df['Inglês'] == 'intermediate'])
advanced_english = len(df.loc[df['Inglês'] == 'advanced'])

# %%
# excel level
basic_excel = len(df.loc[df['Excel'] == 'basic'])
intermediate_excel = len(df.loc[df['Excel'] == 'intermediate'])
advanced_excel = len(df.loc[df['Excel'] == 'advanced'])

# %%
# education
undergraduate = len(df.loc[df['Escolaridade'] == 'Graduação'])
masters = len(df.loc[df['Escolaridade'] == 'Mestrado'])
phd = len(df.loc[df['Escolaridade'] == 'Doutorado'])
high = len(df.loc[df['Escolaridade'] == 'Ensino Médio'])
elementary = len(df.loc[df['Escolaridade'] == 'Ensino Fundamental'])

# %%
# resumé
one_resume = len(df.loc[df['Currículo1'].notna() == True])
two_resume = len(df.loc[df['Currículo2'].notna() == True])

# %%
# Out:
#       Unnamed: 0                           NomeCompleto  \
# 0              0                    Caio César Suguiuti
# 1              1                         Giulia Benutto
# 2              2                       Bruno Leme Valle
# 3              3                  Maria Isabel da Silva
# 4              4                     Sarah Regina Bueno
# 5              5                       Stela Tellarolli
# 6              6                        Victor Mendonça
# 7              7                  Luis Miguel Ticianeli
# 8              8               Tatiane Fernandes Furlan
# 9              9             Alexandre Ribeiro Da Cunha
# 10            10                           Bianca Mello
# 11            11                           Giulia Silva
# 12            12          Melissa Formisano Paccagnella
# 13            13         Marina Augusto Risso de Castro
# 14            14                       Márcio Gabrielli
# 15            15                             Maira Goes
# 16            16                Ester de Paula oliveira
# 17            17                      Lucas Zangerolamo
# 18            18         José Antonio Schewinsky Junior
graduação  https://talentoprod.s3.amazonaws.com/uploads/c...
# 22       Graduação                                                NaN
# 23       Graduação                                                NaN
# 24             NaN                                                NaN
# 25       Graduação  https://talentoprod.s3.amazonaws.com/uploads/c...
# 26       Graduação                                                NaN
# 27             NaN                                                NaN
# 28       Graduação  https://talentoprod.s3.amazonaws.com/uploads/c...
# 29             NaN                                                NaN
# ...            ...                                                ...
# 6588     Graduação                                                NaN
# 6589     Graduação                                                NaN
# 6590     Graduação                                                NaN
# 6591     Graduação  https://talentoprod.s3.amazonaws.com/uploads/c...
# 6592  Ensino Médio     https://linkedin.com/in/in/mayladesouza140397/
# 6593           NaN                                                NaN
# 6594     Graduação  file:///C:/Users/User/Desktop/Cv%20-%20Welling...
# 6595     Graduação  https://buscatextual.cnpq.br/buscatextual/visu...
# 6596     Graduação                                                NaN
# 6597     Graduação                                                NaN
# 6598     Graduação  https://talentoprod.s3.amazonaws.com/uploads/c...
# 6599           NaN                                                NaN
# 6600           NaN                                                NaN
# 6601        Brasil                https://linkedin.com/in/baptistussi
# 6602     Graduação                                                NaN
# 6603     Graduação                                                NaN
# 6604     Graduação                                                NaN
# 6605           NaN                                                NaN
# 6606  Ensino Médio                                                NaN
# 6607     Graduação  https://talentoprod.s3.amazonaws.com/uploads/c...
# 6608           NaN                                                NaN
# 6609     Graduação                                                NaN
# 6610     Graduação                                                NaN
# 6611     Graduação                                                NaN
# 6612     Graduação                                                NaN
# 6613           NaN                                                NaN
# 6614     Graduação                                                NaN
# 6615     Graduação                                                NaN
# 6616     Graduação                                                NaN
# 6617     Graduação             https://linkedin.com/in/vyctoriakarina
#
#                                              Currículo2 AnoDeEntrada  \
# 0                                                   NaN          NaN
# 1                                                   NaN         2017
# 2                                                   NaN         2018
# 3                                                   NaN         2018
# 4                                                   NaN         2016
# 5                                                   NaN         2016
# 6                                                   NaN         2015
# 7                                                   NaN         2017
# 8                                                   NaN         2013
# 9                                                   NaN          NaN
# 10                                                  NaN          NaN
# 11                                                  NaN         2015
# 12                                                  NaN         2014
# 13                                                  NaN         2015
# 14                                                  NaN         2015
# 15                                                  NaN          NaN
# 16                                                  NaN         2018
# 17                                                  NaN         2014
# 18                                                  NaN         2016
# 19                                                  NaN         2016
# 20                                                  NaN         2018
# 21               https://linkedin.com/in/guilhermebersi         2013
# 22                                                  NaN         2008
# 23                                                  NaN         2015
# 24                                                  NaN          NaN
# 25               https://linkedin.com/in/manuelapacheco         2015
# 26                                                  NaN         2013
# 27                                                  NaN          NaN
# 28    https://linkedin.com/in/marília-mugnol-dos-san...         2013
# 29                                                  NaN          NaN
# ...                                                 ...          ...
# 6588                                                NaN         2016
# 6589                                                NaN         2018
# 6590                                                NaN         2016
# 6591  https://linkedin.com/in/caroline-penhalves-656...         2014
# 6592                                                NaN         2012
# 6593                                                NaN          NaN
# 6594                                                NaN         2018
# 6595                                                NaN         2017
# 6596                                                NaN         2018
# 6597                                                NaN         2014
# 6598                                                NaN         2018
# 6599                                                NaN          NaN
# 6600                                                NaN          NaN
# 6601                                                NaN         2011
# 6602                                                NaN         2017
# 6603                                                NaN         2016
# 6604                                                NaN         2016
# 6605                                                NaN          NaN
# 6606                                                NaN         2014
# 6607                                                NaN         2015
# 6608                                                NaN          NaN
# 6609                                                NaN         2015
# 6610                                                NaN         2012
# 6611                                                NaN         2016
# 6612                                                NaN         2016
# 6613                                                NaN          NaN
# 6614                                                NaN         2018
# 6615                                                NaN         2017
# 6616                                                NaN         2018
# 6617                                                NaN         2017
#
#          ...        País        Inglês         Excel  \
# 0        ...         NaN           NaN           NaN
# 1        ...      Brasil  intermediate         basic
# 2        ...      Brasil           NaN           NaN
# 3        ...      Brasil  intermediate      advanced
# 4        ...      Brasil  intermediate         basic
# 5        ...      Brasil      advanced         basic
# 6        ...      Brasil      advanced  intermediate
# 7        ...         NaN           NaN           NaN
# 8        ...      Brasil      advanced      advanced
# 9        ...         NaN           NaN           NaN
# 10       ...         NaN           NaN           NaN
# 11       ...      Brasil  intermediate  intermediate
# 12       ...      Brasil      advanced  intermediate
# 13       ...      Brasil      advanced  intermediate
# 14       ...      Brasil  intermediate      advanced
# 15       ...         NaN           NaN           NaN
# 16       ...      Brasil         basic  intermediate
# 17       ...         NaN           NaN           NaN
# 18       ...      Brasil      advanced      advanced
# 19       ...         NaN           NaN           NaN
# 20       ...      Brasil  intermediate      advanced
# 21       ...      Brasil      advanced  intermediate
# 22       ...         NaN           NaN           NaN
# 23       ...         NaN           NaN           NaN
# 24       ...         NaN           NaN           NaN
# 25       ...      Brasil      advanced      advanced
# 26       ...         NaN           NaN           NaN
# 27       ...         NaN           NaN           NaN
# 28       ...      Brasil      advanced  intermediate
# 29       ...         NaN           NaN           NaN
# ...      ...         ...           ...           ...
# 6588     ...      Brasil           NaN           NaN
# 6589     ...         NaN           NaN           NaN
# 6590     ...         NaN           NaN           NaN
# 6591     ...      Brasil  intermediate  intermediate
# 6592     ...      Brasil  intermediate         basic
# 6593     ...         NaN           NaN           NaN
# 6594     ...      Brasil         basic  intermediate
# 6595     ...      Brasil  intermediate         basic
# 6596     ...         NaN           NaN           NaN
# 6597     ...         NaN           NaN           NaN
# 6598     ...      Brasil         basic           NaN
# 6599     ...         NaN           NaN           NaN
# 6600     ...         NaN           NaN           NaN
# 6601     ...      Brasil      advanced      advanced
# 6602     ...         NaN           NaN           NaN
# 6603     ...      Brasil  intermediate  intermediate
# 6604     ...         NaN           NaN           NaN
# 6605     ...         NaN           NaN           NaN
# 6606     ...         NaN           NaN           NaN
# 6607     ...      Brasil           NaN  intermediate
# 6608     ...         NaN           NaN           NaN
# 6609     ...         NaN           NaN           NaN
# 6610     ...         NaN           NaN           NaN
# 6611     ...         NaN           NaN           NaN
# 6612     ...         NaN           NaN           NaN
# 6613     ...         NaN           NaN           NaN
# 6614     ...         NaN           NaN           NaN
# 6615     ...         NaN           NaN           NaN
# 6616     ...         NaN           NaN           NaN
# 6617     ...      Brasil      advanced  intermediate
#
#                                           Cursos Extras  \
# 0                                                   NaN
# 1     Inglês pela plataforma My English Online (Mini...
# 2                                Excel Avancado (SENAC)
# 3                                           Informática
# 4                                                   NaN
# 5                                                   NaN
# 6                                                   NaN
# 7                                                   NaN
# 8     Excel Aplicado à Engenharia - Do Básico ao Ava...
# 9                                                   NaN
# 10                                                  NaN
# 11                                                  NaN
# 12                                                  NaN
# 13                                                  NaN
# 14                      Licenciamento Ambiental (SENAC)
# 15                                                  NaN
# 16                                                  NaN
# 17                                                  NaN
# 18                              Cursos da área da Udemy
# 19                                                  NaN
# 20               Técnico de Informática, Pacote Office.
# 21                                                  NaN
# 22                                                  NaN
# 23                                                  NaN
# 24                                                  NaN
# 25                                                  NaN
# 26                                                  NaN
# 27                                                  NaN
# 28    General Business Program (BTC), Marketing Estr...
# 29                                                  NaN
# ...                                                 ...
# 6588                                                NaN
# 6589                                                NaN
# 6590                                                NaN
# 6591                                                NaN
# 6592   Técnico em Secretariado pela ETEC de Hortolândia
# 6593                                                NaN
# 6594                                        Informática
# 6595  Avaliação do risco de queda de árvores urbanas...
# 6596                                                NaN
# 6597                                                NaN
# 6598                                                NaN
# 6599                                                NaN
# 6600                                                NaN
# 6601                                        Yellow Belt
# 6602                                                NaN
# 6603                                                NaN
# 6604                                                NaN
# 6605                                                NaN
# 6606                                                NaN
# 6607                                                NaN
# 6608                                                NaN
# 6609                                                NaN
# 6610                                                NaN
# 6611                                                NaN
# 6612                                                NaN
# 6613                                                NaN
# 6614                                                NaN
# 6615                                                NaN
# 6616                                                NaN
# 6617            Python, C#, Redes, Informática avançada
#
#                                Outros Idiomas  \
# 0                                         NaN
# 1                             Espanhol báscio
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# 5                                         NaN
# 6                                         NaN
# 7                                         NaN
# 8                            Francês Avançado
# 9                                         NaN
# 10                                        NaN
# 11                                        NaN
# 12                            Italiano básico
# 13    Inglês Avançado, Espanhol Intermediário
# 14                   Espanhol (Intermediário)
# 15                                        NaN
# 16                                        NaN
# 17                                        NaN
# 18                     Espanhol Intermediário
# 19                                        NaN
# 20                                        NaN
# 21                     Espanhol intermediário
# 22                                        NaN
# 23                                        NaN
# 24                                        NaN
# 25                                        NaN
# 26                                        NaN
# 27                                        NaN
# 28                                        NaN
# 29                                        NaN
# ...                                       ...
# 6588                                      NaN
# 6589                                      NaN
# 6590                                      NaN
# 6591                                      NaN
# 6592                                      NaN
# 6593                                      NaN
# 6594                                      NaN
# 6595                                      NaN
# 6596                                      NaN
# 6597                                      NaN
# 6598                                      NaN
# 6599                                      NaN
# 6600                                      NaN
# 6601                          Espanhol básico
# 6602                                      NaN
# 6603                                      NaN
# 6604                                      NaN
# 6605                                      NaN
# 6606                                      NaN
# 6607                                      NaN
# 6608                                      NaN
# 6609                                      NaN
# 6610                                      NaN
# 6611                                      NaN
# 6612                                      NaN
# 6613                                      NaN
# 6614                                      NaN
# 6615                                      NaN
# 6616                                      NaN
# 6617                                      NaN
#
#                                              Interesses Pode se mudar  \
# 0                                                   NaN           NaN
# 1            Industria, educação, pesquisa e hospitalar          True
# 2     Financeiro, pesquisa, excel, design thinking e...          True
# 3                                            Financeiro          True
# 4                            Pesquisa e desenvolvimento         False
# 5                               Consultoria, manutenção         False
# 6             Liderança, mercado financeiro, consutoria          True
# 7                 Tecnologia, Empresarial e Consultoria         False
# 8           Consultoria, Estratégia e Gestão, Operações          True
# 9                                                   NaN           NaN
# 10                                                  NaN           NaN
# 11                                            Qualidade         False
# 12    Controle de Qualidade, Gerenciamento de Qualidade          True
# 13    Recursos Humanos, Marketing, Financeiro, Admin...          True
# 14                            Saneamento, Meio Ambiente         False
# 15                                                  NaN           NaN
# 16                                 finaceiro, pesquisas          True
# 17                                             Pesquisa         False
# 18                                         Data Science         False
# 19                                        administração         False
# 20                 Contabilidade, finanças, estatistica          True
# 21                                           Engenharia         False
# 22                                           Financeiro         False
# 23                              Pesquisa, parte técnica         False
# 24                                                  NaN           NaN
# 25    Consultoria, além de indústrias de alimentos e...          True
# 26                  Engenharia, consultoria, financeira         False
# 27                                                  NaN           NaN
# 28                   Consultoria,  Planejamento, Gestão          True
# 29                                                  NaN           NaN
# ...                                                 ...           ...
# 6588  Engenharia de qualidade, Logística, Ambiental,...         False
# 6589                               Financeiro, pesquisa         False
# 6590                                  Mecanica em geral         False
# 6591                PCP, Auditoria, Gestão da Qualidade          True
# 6592                        Administração, Secretariado         False
# 6593                                                NaN           NaN
# 6594                          Consultoria e Atendimento         False
# 6595          Pesquisa em botânica, ecologia e anatomia         False
# 6596                                         Financeiro         False
# 6597                                Engenharia, Quimica         False
# 6598                             eletrônica, automação,          True
# 6599                                                NaN           NaN
# 6600                                                NaN           NaN
# 6601        Engenharia, Manutenção, TI, Desenvolvimento          True
# 6602                                               Tudo         False
# 6603                   Indústria, inovação e tecnologia          True
# 6604                                           pesquisa         False
# 6605                                                NaN           NaN
# 6606                                         financeiro         False
# 6607                                Desenvolvimento web          True
# 6608                                                NaN           NaN
# 6609                                           Finanças         False
# 6610                       Psicologia, recursos humanos         False
# 6611      Mercado financeiro, comércio exterior, bancos         False
# 6612                                         Engenharia         False
# 6613                                                NaN           NaN
# 6614                       Economia, gestão de recursos         False
# 6615  Pesquisa, planejamento urbano, patrimonio cult...         False
# 6616                                                 RH         False
# 6617                                                 TI         False
#
#      Primeira Vez                   Referência      Status
# 0             NaN                          NaN  unverified
# 1            True          através do facebook   confirmed
# 2            True                     Facebook   checkedin
# 3           False                       Amigos  unverified
# 4            True                       Amigos   confirmed
# 5            True                     Facebook    admitted
# 6            True                     Facebook   checkedin
# 7            True                     Facebook   confirmed
# 8            True                     Facebook   confirmed
# 9             NaN                          NaN  incomplete
# 10            NaN                          NaN  incomplete
# 11          False                        Amigo   checkedin
# 12           True                     Facebook    withdraw
# 13          False                     Facebook   confirmed
# 14           True                        amigo   confirmed
# 15            NaN                          NaN  incomplete
# 16           True                        amigo   confirmed
# 17          False     Já visitei outras vezes.   confirmed
# 18           True                     Facebook   confirmed
# 19           True                        Senac   checkedin
# 20           True                        Amigo    admitted
# 21          False                     Facebook   checkedin
# 22          False                       Amigos   checkedin
# 23          False                     Facebook   checkedin
# 24            NaN                          NaN  incomplete
# 25           True                       Amigos   checkedin
# 26          False                        Amigo   confirmed
# 27            NaN                          NaN  incomplete
# 28          False                     Facebook   confirmed
# 29            NaN                          NaN  incomplete
# ...           ...                          ...         ...
# 6588         True  Facebook, Amigos, Faculdade   checkedin
# 6589         True                        Amigo   checkedin
# 6590         True             Amigos indicacao   checkedin
# 6591        False                     Parentes   checkedin
# 6592         True               Por familiares   checkedin
# 6593          NaN                          NaN  incomplete
# 6594         True                      Parente    withdraw
# 6595         True                Matéria do G1   checkedin
# 6596         True                         Amig   checkedin
# 6597         True                         Site   checkedin
# 6598         True                         EPTV    admitted
# 6599          NaN                          NaN  incomplete
# 6600          NaN                          NaN  incomplete
# 6601         True                        Amigo   checkedin
# 6602         True                     Facebook   checkedin
# 6603        False                     Facebook   checkedin
# 6604         True                       E-mail   checkedin
# 6605          NaN                          NaN  incomplete
# 6606         True                        amigo   checkedin
# 6607         True             Através de amigo    admitted
# 6608          NaN                          NaN  incomplete
# 6609         True                      Unicamp   checkedin
# 6610         True    Visualizou, redes sociais   checkedin
# 6611        False                       Amigos   checkedin
# 6612         True                      Unicamp   checkedin
# 6613          NaN                          NaN  incomplete
# 6614        False                     Facebook   checkedin
# 6615         True                 Visualizando   checkedin
# 6616        False           ediçoes anteriores   checkedin
# 6617         True                        Amigo    withdraw
#
# [6618 rows x 24 columns]
